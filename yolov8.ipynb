# %%
# !pip install ultralytics
# !pip install roboflow

import ultralytics
ultralytics.checks()


from roboflow import Roboflow
rf = Roboflow(api_key="vJYuOdNBMeQOqrD1DHi9")
project = rf.workspace("yolo-klrym").project("object-detection-htfhu")
version = project.version(7)
dataset = version.download("yolov8-obb")

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=/kaggle/working/Object-Detection-7/data.yaml epochs=100 imgsz=640 save_period=20
#save sau 20 epoch

# %%
#resume
# !yolo task=detect mode=train model=path/to/checkpoint.pt data=C:/yolo_data/data.yaml epochs=150 imgsz=640 --resume
#tiep tuc train neu bi time out ma van giu save epoch

# %%
# !yolo task=detect mode=val model={HOME}/runs/detect/train/weights/best.pt data={dataset.location}/data.yaml
#detect model da train

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train/weights/best.pt source=/content/4.jpg save=True

#test

# %%
# !zip -r working.zip /kaggle/working/
